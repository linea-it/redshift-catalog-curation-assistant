# %% [markdown]
# # Redshift Catalog Curation Assistant notebook
#
# This notebook is a lightweight placeholder for future project-specific tutorials. Published notebooks should use small versioned inputs and demonstrate maintained CLI or Python workflows.

# %%
import redshift_catalog_curation_assistant as rcca

rcca.__version__
